# %% [markdown]
# <a href="https://colab.research.google.com/github/mhshobeiribasu2/similarimagedetection/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip 'ImageSimilarityDetection.zip'
# Out:
# Archive:  ImageSimilarityDetection.zip
#    creating: ImageSimilarityDetection/
#    creating: ImageSimilarityDetection/.git/
#   inflating: ImageSimilarityDetection/.git/config
#   inflating: ImageSimilarityDetection/.git/description
#   inflating: ImageSimilarityDetection/.git/HEAD
#    creating: ImageSimilarityDetection/.git/hooks/
#   inflating: ImageSimilarityDetection/.git/hooks/applypatch-msg.sample
#   inflating: ImageSimilarityDetection/.git/hooks/commit-msg.sample
#   inflating: ImageSimilarityDetection/.git/hooks/fsmonitor-watchman.sample
#   inflating: ImageSimilarityDetection/.git/hooks/post-update.sample
#   inflating: ImageSimilarityDetection/.git/hooks/pre-applypatch.sample
#   inflating: ImageSimilarityDetection/.git/hooks/pre-commit.sample
#   inflating: ImageSimilarityDetection/.git/hooks/pre-merge-commit.sample
#   inflating: ImageSimilarityDetection/.git/hooks/pre-push.sample
#   inflating: ImageSimilarityDetection/.git/hooks/pre-rebase.sample
#   inflating: ImageSimilarityDetection/.git/hooks/pre-receive.sample
#   inflating: ImageSimilarityDetection/.git/hooks/prepare-commit-msg.sample
#   inflating: ImageSimilarityDetection/.git/hooks/push-to-checkout.sample
#   inflating: ImageSimilarityDetection/.git/hooks/update.sample
#   inflating: ImageSimilarityDetection/.git/index
#    creating: ImageSimilarityDetection/.git/info/
#   inflating: ImageSimilarityDetection/.git/info/exclude
#    creating: ImageSimilarityDetection/.git/logs/
#   inflating: ImageSimilarityDetection/.git/logs/HEAD
#    creating: ImageSimilarityDetection/.git/logs/refs/
#    creating: ImageSimilarityDetection/.git/logs/refs/heads/
#   inflating: ImageSimilarityDetection/.git/logs/refs/heads/master
#    creating: ImageSimilarityDetection/.git/logs/refs/remotes/
#    creating: ImageSimilarityDetection/.git/logs/refs/remotes/origin/
#   inflating: ImageSimilarityDetection/.git/logs/refs/remotes/origin/HEAD
#    creating: ImageSimilarityDetection/.git/objects/
#    creating: ImageSimilarityDetection/.git/objects/info/
#    creating: ImageSimilarityDetection/.git/objects/pack/
#   inflating: ImageSimilarityDetection/.git/objects/pack/pack-bdc5f6cc88c605e176c448b21c036ff7714a75a5.idx
#   inflating: ImageSimilarityDetection/.git/objects/pack/pack-bdc5f6cc88c605e176c448b21c036ff7714a75a5.pack
#   inflating: ImageSimilarityDetection/.git/packed-refs
#    creating: ImageSimilarityDetection/.git/refs/
#    creating: ImageSimilarityDetection/.git/refs/heads/
#   inflating: ImageSimilarityDetection/.git/refs/heads/master
#    creating: ImageSimilarityDetection/.git/refs/remotes/
#    creating: ImageSimilarityDetection/.git/refs/remotes/origin/
#   inflating: ImageSimilarityDetection/.git/refs/remotes/origin/HEAD
#    creating: ImageSimilarityDetection/.git/refs/tags/
#    creating: ImageSimilarityDetection/.ipynb_checkpoints/
#   inflating: ImageSimilarityDetection/.ipynb_checkpoints/cluster_image_feature_vectors-checkpoint.py
#   inflating: ImageSimilarityDetection/.ipynb_checkpoints/get_image_feature_vectors-checkpoint.py
#   inflating: ImageSimilarityDetection/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#   inflating: ImageSimilarityDetection/cluster_image_feature_vectors.py
#   inflating: ImageSimilarityDetection/get_image_feature_vectors.py
#   inflating: ImageSimilarityDetection/image_data.json
#   inflating: ImageSimilarityDetection/nearest_neighbors.json
#   inflating: ImageSimilarityDetection/README.md
#    creating: ImageSimilarityDetection/test/
#   inflating: ImageSimilarityDetection/test/0536ef5660e47128e9fde8a25f547db0785b2851.jpg
#   inflating: ImageSimilarityDetection/test/0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46.jpg
#   inflating: ImageSimilarityDetection/test/0b96264a36e951c2cb4fba7c3cd913fc0274cba4.jpg
#   inflating: ImageSimilarityDetection/test/114b8d92dfe9d1c38719135bc885a2220636eca3.jpg
#   inflating: ImageSimilarityDetection/test/14f54167bfbf4393f0990334efb292242576bb51.jpg
#   inflating: ImageSimilarityDetection/test/158c42c84260dafc49793ce3a2e7fac1b73fba5e.jpg
#   inflating: ImageSimilarityDetection/test/22abf56814e371a73528d22848889f84168dc29a.jpg
#   inflating: ImageSimilarityDetection/test/2e7d3fa1d6bb03ec34328e705c23808f4bf11f76.jpg
#   inflating: ImageSimilarityDetection/test/2ed31f58c2be08027b4d060dca7b80d905e9213b.jpg
#   inflating: ImageSimilarityDetection/test/3093418aba5897313303ae15e43275671fabe473.jpg
#   inflating: ImageSimilarityDetection/test/46921cd403370e7ab8a098843adaf29cb230537d.jpg
#   inflating: ImageSimilarityDetection/test/4a2f509d8e9def9dd5681d36c3045f648dc6e1bf.jpg
#   inflating: ImageSimilarityDetection/test/4dad9e43db72c2609856b02abced3755ef566383.jpg
#   inflating: ImageSimilarityDetection/test/535d914ddb7bedac122a9c158012a52defbdb28e.jpg
#   inflating: ImageSimilarityDetection/test/5b7ea4ab23dfd89d1a66ae2f256826e5c8783140.jpg
#   inflating: ImageSimilarityDetection/test/623b50a4f2965c9fe8c453487dd288f998b51297.jpg
#   inflating: ImageSimilarityDetection/test/6e98e17cfef862fa83abdf351a23310d608b2b20.jpg
#   inflating: ImageSimilarityDetection/test/73359c7cf3b04499250039ccb456eb168afa8704.jpg
#   inflating: ImageSimilarityDetection/test/76e7932694833640c2af61030e40fd72997e7e24.jpg
#   inflating: ImageSimilarityDetection/test/77e23064334f0ab47f9bd17e232bdd941b2e6c1d.jpg
#   inflating: ImageSimilarityDetection/test/8893ea64a332765217b26680f925342a1bb4d301.jpg
#   inflating: ImageSimilarityDetection/test/8e021fac89810edd9a8529814ecab1573d68b084.jpg
#   inflating: ImageSimilarityDetection/test/9769d5e06b3981d39dc1891d6da2ce8462c1c0a3.jpg
#   inflating: ImageSimilarityDetection/test/9b79dd411d42124016196b989bdf314838f48de2.jpg
#   inflating: ImageSimilarityDetection/test/9e34b9687d45408f7c739e020bb38ae7e562e23f.jpg
#   inflating: ImageSimilarityDetection/test/a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7.jpg
#   inflating: ImageSimilarityDetection/test/a18b4d927b103b36451835047f7a1c223908f228.jpg
#   inflating: ImageSimilarityDetection/test/a940aa2eb44907bb22ad16182df5dd093b97e38c.jpg
#   inflating: ImageSimilarityDetection/test/a9e393eb434fe21bd20f718c4c752f819d3acba3.jpg
#   inflating: ImageSimilarityDetection/test/aeb31fa7538c4c38743afe3b5d181ffc2c504427.jpg
#   inflating: ImageSimilarityDetection/test/b2215523a1384c5583588a831b1a008e94ab2236.jpg
#   inflating: ImageSimilarityDetection/test/b3179a1855d492eb3313b59b82a1e29e8850eb92.jpg
#   inflating: ImageSimilarityDetection/test/b585040bac837350fe18272763a73b9ac069aa09.jpg
#   inflating: ImageSimilarityDetection/test/bb41ffeba7262ad30e7e76d7ba6cce2904c90782.jpg
#   inflating: ImageSimilarityDetection/test/bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf.jpg
#   inflating: ImageSimilarityDetection/test/bfa750035da255ec6d0f71df34ac3a759e801bbf.jpg
#   inflating: ImageSimilarityDetection/test/c2535cf647be0949529ddb8e78beaaf79ac0bd53.jpg
#   inflating: ImageSimilarityDetection/test/c2c0fff79e0b65a818412572e9f9364bc359fb4f.jpg
#   inflating: ImageSimilarityDetection/test/c715c4465c351f0b06415fb9a1ccbd946327fb23.jpg
#   inflating: ImageSimilarityDetection/test/cba20840f15f48fae6ddaacac0721df80ae63ad8.jpg
#   inflating: ImageSimilarityDetection/test/cd8320501898da6979a844f621b3a97f9f76ba0c.jpg
#   inflating: ImageSimilarityDetection/test/d8b30ba9b6f342c670ca0086857926cbbad4508d.jpg
#   inflating: ImageSimilarityDetection/test/dc09ad64aa6f60ae863d2547652d89d2a1e4f508.jpg
#   inflating: ImageSimilarityDetection/test/e5dddf21df0ffefc2b3b6848c701b28d42477dec.jpg
#   inflating: ImageSimilarityDetection/test/e95a8e4c52075aaa389d3d2b031c39c5570a1d99.jpg
#   inflating: ImageSimilarityDetection/test/f170378bdd1be7568992468443d7454e1f3d24f9.jpg
#   inflating: ImageSimilarityDetection/test/f4748df6bae208df39ac33e4d2e88ef51673666a.jpg
#   inflating: ImageSimilarityDetection/test/f5d05c38a69a94a93fec7e8ee357d701dc2308d9.jpg
#   inflating: ImageSimilarityDetection/test/f7aaabd886d4f7b8736dcb4055abd94301dc846d.jpg
#   inflating: ImageSimilarityDetection/test/fd27283a5a01a7a4d4b153d4de4b38117a94f4b8.jpg
#   inflating: ImageSimilarityDetection/Untitled.ipynb

# %%
# !pip install annoy
# Out:
# Collecting annoy
#   Downloading annoy-1.17.0.tar.gz (646 kB)
#      |████████████████████████████████| 646 kB 7.5 MB/s
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.0-cp37-cp37m-linux_x86_64.whl size=391671 sha256=27d0a52cf1a285a26e4c65ef2029b13075d8648754b49be211c092a73fb3fff0
#   Stored in directory: /root/.cache/pip/wheels/4f/e8/1e/7cc9ebbfa87a3b9f8ba79408d4d31831d67eea918b679a4c07
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.17.0

# %%
#################################################
# Imports and function definitions
#################################################
# For running inference on the TF-Hub module.
import tensorflow as tf
import tensorflow_hub as hub

# For saving 'feature vectors' into a txt file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path
#################################################

#################################################
# This function:
# Loads the JPEG image at the given path
# Decodes the JPEG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor
#################################################
def load_img(path):

  # Reads the image file and returns data type of string
  img = tf.io.read_file(path)

  # Decodes the image to W x H x 3 shape tensor with type of uint8
  img = tf.io.decode_jpeg(img, channels=3)

  # Resize the image to 224 x 244 x 3 shape tensor
  img = tf.image.resize_with_pad(img, 224, 224)

  # Converts the data type of uint8 to float32 by adding a new axis
  # This makes the img 1 x 224 x 224 x 3 tensor with the data type of float32
  # This is required for the mobilenet model we are using
  img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]

  return img

#################################################
# This function:
# Loads the mobilenet model in TF.HUB
# Makes an inference for all images stored in a local folder
# Saves each of the feature vectors in a file
#################################################
def get_image_feature_vectors():

  i = 0

  start_time = time.time()

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at %s" %time.ctime())
  print("---------------------------------")

  # Definition of module with using tfhub.dev handle
  module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4" 
  
  # Load the module
  module = hub.load(module_handle)

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors -  Started at %s" %time.ctime())
 

  # Loops through all images in a local folder
  for filename in glob.glob('1/test/*.jpg'): #assuming gif
    i = i + 1

    print("-----------------------------------------------------------------------------------------")
    print("Image count                     :%s" %i)
    print("Image in process is             :%s" %filename)

    # Loads and pre-process the image
    img = load_img(filename)

    # Calculate the image feature vector of the img
    features = module(img)   
  
    # Remove single-dimensional entries from the 'features' array
    feature_set = np.squeeze(features)  

    # Saves the image feature vectors into a file for later use

    outfile_name = os.path.basename(filename).split('.')[0] + ".npz"
    out_path = os.path.join('1/test/', outfile_name)

    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')

    print("Image feature vector saved to   :%s" %out_path)
  
  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors - Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))
  print("--- %s images processed ---------" %i)
    
get_image_feature_vectors()



#################################################
# This script reads image feature vectors from a folder
# and saves the image similarity scores in json file
# by Erdem Isbilen - December/2019
#################################################

#################################################
# Imports and function definitions
#################################################

# Numpy for loading image feature vectors from file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# json for storing data in json file
import json

# Annoy and Scipy for similarity calculation
from annoy import AnnoyIndex
from scipy import spatial
#################################################

#################################################
# This function reads from 'image_data.json' file
# Looks for a specific 'filename' value
# Returns the product id when product image names are matched 
# So it is used to find product id based on the product image name
#################################################
def match_id(filename):
  with open('1/image_data.json') as json_file:
    
    for file in json_file:
        seen = json.loads(file)

        for line in seen:
          
          if filename==line['imageName']:
            print(line)
            return line['productId']
            break
#################################################

#################################################
# This function; 
# Reads all image feature vectores stored in /feature-vectors/*.npz
# Adds them all in Annoy Index
# Builds ANNOY index
# Calculates the nearest neighbors and image similarity metrics
# Stores image similarity scores with productID in a json file
#################################################
def cluster():

  start_time = time.time()
  
  print("---------------------------------")
  print ("Step.1 - ANNOY index generation - Started at %s" %time.ctime())
  print("---------------------------------")

  # Defining data structures as empty dict
  file_index_to_file_name = {}
  file_index_to_file_vector = {}
  file_index_to_product_id = {}

  # Configuring annoy parameters
  dims = 1792
  n_nearest_neighbors = 20
  trees = 10000

  # Reads all file names which stores feature vectors 
  allfiles = glob.glob('1/test/*.npz')

  t = AnnoyIndex(dims, metric='angular')

  for file_index, i in enumerate(allfiles):
    
    # Reads feature vectors and assigns them into the file_vector 
    file_vector = np.loadtxt(i)

    # Assigns file_name, feature_vectors and corresponding product_id
    file_name = os.path.basename(i).split('.')[0]
    file_index_to_file_name[file_index] = file_name
    file_index_to_file_vector[file_index] = file_vector
    file_index_to_product_id[file_index] = match_id(file_name)

    # Adds image feature vectors into annoy index   
    t.add_item(file_index, file_vector)

    print("---------------------------------")
    print("Annoy index     : %s" %file_index)
    print("Image file name : %s" %file_name)
    print("Product id      : %s" %file_index_to_product_id[file_index])
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))


  # Builds annoy index
  t.build(trees)

  print ("Step.1 - ANNOY index generation - Finished")
  print ("Step.2 - Similarity score calculation - Started ") 
  
  named_nearest_neighbors = []

  # Loops through all indexed items
  for i in file_index_to_file_name.keys():

    # Assigns master file_name, image feature vectors and product id values
    master_file_name = file_index_to_file_name[i]
    master_vector = file_index_to_file_vector[i]
    master_product_id = file_index_to_product_id[i]

    # Calculates the nearest neighbors of the master item
    nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)

    # Loops through the nearest neighbors of the master item
    for j in nearest_neighbors:

      print(j)

      # Assigns file_name, image feature vectors and product id values of the similar item
      neighbor_file_name = file_index_to_file_name[j]
      neighbor_file_vector = file_index_to_file_vector[j]
      neighbor_product_id = file_index_to_product_id[j]

      # Calculates the similarity score of the similar item
      similarity = 1 - spatial.distance.cosine(master_vector, neighbor_file_vector)
      rounded_similarity = int((similarity * 10000)) / 10000.0

      # Appends master product id with the similarity score 
      # and the product id of the similar items
      named_nearest_neighbors.append({
        'similarity': rounded_similarity,
        'master_pi': master_product_id,
        'similar_pi': neighbor_product_id})

    print("---------------------------------") 
    print("Similarity index       : %s" %i)
    print("Master Image file name : %s" %file_index_to_file_name[i]) 
    print("Nearest Neighbors.     : %s" %nearest_neighbors) 
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  
  print ("Step.2 - Similarity score calculation - Finished ") 

  # Writes the 'named_nearest_neighbors' to a json file
  with open('1/nearest_neighbors.json', 'w') as out:
    json.dump(named_nearest_neighbors, out)

  print ("Step.3 - Data stored in 'nearest_neighbors.json' file ") 
  print("--- Prosess completed in %.2f minutes ---------" % ((time.time() - start_time)/60))

cluster()
# Out:
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at Sun Apr  3 10:52:07 2022
# ---------------------------------
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at Sun Apr  3 10:52:10 2022
# --- 0.05 minutes passed ---------
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors -  Started at Sun Apr  3 10:52:10 2022
# -----------------------------------------------------------------------------------------
# Image count                     :1
# Image in process is             :1/test/73359c7cf3b04499250039ccb456eb168afa8704.jpg
# Image feature vector saved to   :1/test/73359c7cf3b04499250039ccb456eb168afa8704.npz
# -----------------------------------------------------------------------------------------
# Image count                     :2
# Image in process is             :1/test/a9e393eb434fe21bd20f718c4c752f819d3acba3.jpg
# Image feature vector saved to   :1/test/a9e393eb434fe21bd20f718c4c752f819d3acba3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :3
# Image in process is             :1/test/f170378bdd1be7568992468443d7454e1f3d24f9.jpg
# Image feature vector saved to   :1/test/f170378bdd1be7568992468443d7454e1f3d24f9.npz
# -----------------------------------------------------------------------------------------
# Image count                     :4
# Image in process is             :1/test/4dad9e43db72c2609856b02abced3755ef566383.jpg
# Image feature vector saved to   :1/test/4dad9e43db72c2609856b02abced3755ef566383.npz
# -----------------------------------------------------------------------------------------
# Image count                     :5
# Image in process is             :1/test/dc09ad64aa6f60ae863d2547652d89d2a1e4f508.jpg
# Image feature vector saved to   :1/test/dc09ad64aa6f60ae863d2547652d89d2a1e4f508.npz
# -----------------------------------------------------------------------------------------
# Image count                     :6
# Image in process is             :1/test/46921cd403370e7ab8a098843adaf29cb230537d.jpg
# Image feature vector saved to   :1/test/46921cd403370e7ab8a098843adaf29cb230537d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :7
# Image in process is             :1/test/e95a8e4c52075aaa389d3d2b031c39c5570a1d99.jpg
# Image feature vector saved to   :1/test/e95a8e4c52075aaa389d3d2b031c39c5570a1d99.npz
# -----------------------------------------------------------------------------------------
# Image count                     :8
# Image in process is             :1/test/b3179a1855d492eb3313b59b82a1e29e8850eb92.jpg
# Image feature vector saved to   :1/test/b3179a1855d492eb3313b59b82a1e29e8850eb92.npz
# -----------------------------------------------------------------------------------------
# Image count                     :9
# Image in process is             :1/test/c715c4465c351f0b06415fb9a1ccbd946327fb23.jpg
# Image feature vector saved to   :1/test/c715c4465c351f0b06415fb9a1ccbd946327fb23.npz
# -----------------------------------------------------------------------------------------
# Image count                     :10
# Image in process is             :1/test/0536ef5660e47128e9fde8a25f547db0785b2851.jpg
# Image feature vector saved to   :1/test/0536ef5660e47128e9fde8a25f547db0785b2851.npz
# -----------------------------------------------------------------------------------------
# Image count                     :11
# Image in process is             :1/test/cd8320501898da6979a844f621b3a97f9f76ba0c.jpg
# Image feature vector saved to   :1/test/cd8320501898da6979a844f621b3a97f9f76ba0c.npz
# -----------------------------------------------------------------------------------------
# Image count                     :12
# Image in process is             :1/test/fd27283a5a01a7a4d4b153d4de4b38117a94f4b8.jpg
# Image feature vector saved to   :1/test/fd27283a5a01a7a4d4b153d4de4b38117a94f4b8.npz
# -----------------------------------------------------------------------------------------
# Image count                     :13
# Image in process is             :1/test/158c42c84260dafc49793ce3a2e7fac1b73fba5e.jpg
# Image feature vector saved to   :1/test/158c42c84260dafc49793ce3a2e7fac1b73fba5e.npz
# -----------------------------------------------------------------------------------------
# Image count                     :14
# Image in process is             :1/test/c2c0fff79e0b65a818412572e9f9364bc359fb4f.jpg
# Image feature vector saved to   :1/test/c2c0fff79e0b65a818412572e9f9364bc359fb4f.npz
# -----------------------------------------------------------------------------------------
# Image count                     :15
# Image in process is             :1/test/0b96264a36e951c2cb4fba7c3cd913fc0274cba4.jpg
# Image feature vector saved to   :1/test/0b96264a36e951c2cb4fba7c3cd913fc0274cba4.npz
# -----------------------------------------------------------------------------------------
# Image count                     :16
# Image in process is             :1/test/d8b30ba9b6f342c670ca0086857926cbbad4508d.jpg
# Image feature vector saved to   :1/test/d8b30ba9b6f342c670ca0086857926cbbad4508d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :17
# Image in process is             :1/test/4a2f509d8e9def9dd5681d36c3045f648dc6e1bf.jpg
# Image feature vector saved to   :1/test/4a2f509d8e9def9dd5681d36c3045f648dc6e1bf.npz
# -----------------------------------------------------------------------------------------
# Image count                     :18
# Image in process is             :1/test/a18b4d927b103b36451835047f7a1c223908f228.jpg
# Image feature vector saved to   :1/test/a18b4d927b103b36451835047f7a1c223908f228.npz
# -----------------------------------------------------------------------------------------
# Image count                     :19
# Image in process is             :1/test/76e7932694833640c2af61030e40fd72997e7e24.jpg
# Image feature vector saved to   :1/test/76e7932694833640c2af61030e40fd72997e7e24.npz
# -----------------------------------------------------------------------------------------
# Image count                     :20
# Image in process is             :1/test/5b7ea4ab23dfd89d1a66ae2f256826e5c8783140.jpg
# Image feature vector saved to   :1/test/5b7ea4ab23dfd89d1a66ae2f256826e5c8783140.npz
# -----------------------------------------------------------------------------------------
# Image count                     :21
# Image in process is             :1/test/8e021fac89810edd9a8529814ecab1573d68b084.jpg
# Image feature vector saved to   :1/test/8e021fac89810edd9a8529814ecab1573d68b084.npz
# -----------------------------------------------------------------------------------------
# Image count                     :22
# Image in process is             :1/test/535d914ddb7bedac122a9c158012a52defbdb28e.jpg
# Image feature vector saved to   :1/test/535d914ddb7bedac122a9c158012a52defbdb28e.npz
# -----------------------------------------------------------------------------------------
# Image count                     :23
# Image in process is             :1/test/f7aaabd886d4f7b8736dcb4055abd94301dc846d.jpg
# Image feature vector saved to   :1/test/f7aaabd886d4f7b8736dcb4055abd94301dc846d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :24
# Image in process is             :1/test/8893ea64a332765217b26680f925342a1bb4d301.jpg
# Image feature vector saved to   :1/test/8893ea64a332765217b26680f925342a1bb4d301.npz
# -----------------------------------------------------------------------------------------
# Image count                     :25
# Image in process is             :1/test/e5dddf21df0ffefc2b3b6848c701b28d42477dec.jpg
# Image feature vector saved to   :1/test/e5dddf21df0ffefc2b3b6848c701b28d42477dec.npz
# -----------------------------------------------------------------------------------------
# Image count                     :26
# Image in process is             :1/test/14f54167bfbf4393f0990334efb292242576bb51.jpg
# Image feature vector saved to   :1/test/14f54167bfbf4393f0990334efb292242576bb51.npz
# -----------------------------------------------------------------------------------------
# Image count                     :27
# Image in process is             :1/test/22abf56814e371a73528d22848889f84168dc29a.jpg
# Image feature vector saved to   :1/test/22abf56814e371a73528d22848889f84168dc29a.npz
# -----------------------------------------------------------------------------------------
# Image count                     :28
# Image in process is             :1/test/0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46.jpg
# Image feature vector saved to   :1/test/0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46.npz
# -----------------------------------------------------------------------------------------
# Image count                     :29
# Image in process is             :1/test/f4748df6bae208df39ac33e4d2e88ef51673666a.jpg
# Image feature vector saved to   :1/test/f4748df6bae208df39ac33e4d2e88ef51673666a.npz
# -----------------------------------------------------------------------------------------
# Image count                     :30
# Image in process is             :1/test/b585040bac837350fe18272763a73b9ac069aa09.jpg
# Image feature vector saved to   :1/test/b585040bac837350fe18272763a73b9ac069aa09.npz
# -----------------------------------------------------------------------------------------
# Image count                     :31
# Image in process is             :1/test/cba20840f15f48fae6ddaacac0721df80ae63ad8.jpg
# Image feature vector saved to   :1/test/cba20840f15f48fae6ddaacac0721df80ae63ad8.npz
# -----------------------------------------------------------------------------------------
# Image count                     :32
# Image in process is             :1/test/77e23064334f0ab47f9bd17e232bdd941b2e6c1d.jpg
# Image feature vector saved to   :1/test/77e23064334f0ab47f9bd17e232bdd941b2e6c1d.npz
# -----------------------------------------------------------------------------------------
# Image count                     :33
# Image in process is             :1/test/3093418aba5897313303ae15e43275671fabe473.jpg
# Image feature vector saved to   :1/test/3093418aba5897313303ae15e43275671fabe473.npz
# -----------------------------------------------------------------------------------------
# Image count                     :34
# Image in process is             :1/test/9e34b9687d45408f7c739e020bb38ae7e562e23f.jpg
# Image feature vector saved to   :1/test/9e34b9687d45408f7c739e020bb38ae7e562e23f.npz
# -----------------------------------------------------------------------------------------
# Image count                     :35
# Image in process is             :1/test/bb41ffeba7262ad30e7e76d7ba6cce2904c90782.jpg
# Image feature vector saved to   :1/test/bb41ffeba7262ad30e7e76d7ba6cce2904c90782.npz
# -----------------------------------------------------------------------------------------
# Image count                     :36
# Image in process is             :1/test/a940aa2eb44907bb22ad16182df5dd093b97e38c.jpg
# Image feature vector saved to   :1/test/a940aa2eb44907bb22ad16182df5dd093b97e38c.npz
# -----------------------------------------------------------------------------------------
# Image count                     :37
# Image in process is             :1/test/9769d5e06b3981d39dc1891d6da2ce8462c1c0a3.jpg
# Image feature vector saved to   :1/test/9769d5e06b3981d39dc1891d6da2ce8462c1c0a3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :38
# Image in process is             :1/test/c2535cf647be0949529ddb8e78beaaf79ac0bd53.jpg
# Image feature vector saved to   :1/test/c2535cf647be0949529ddb8e78beaaf79ac0bd53.npz
# -----------------------------------------------------------------------------------------
# Image count                     :39
# Image in process is             :1/test/f5d05c38a69a94a93fec7e8ee357d701dc2308d9.jpg
# Image feature vector saved to   :1/test/f5d05c38a69a94a93fec7e8ee357d701dc2308d9.npz
# -----------------------------------------------------------------------------------------
# Image count                     :40
# Image in process is             :1/test/623b50a4f2965c9fe8c453487dd288f998b51297.jpg
# Image feature vector saved to   :1/test/623b50a4f2965c9fe8c453487dd288f998b51297.npz
# -----------------------------------------------------------------------------------------
# Image count                     :41
# Image in process is             :1/test/bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf.jpg
# Image feature vector saved to   :1/test/bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf.npz
# -----------------------------------------------------------------------------------------
# Image count                     :42
# Image in process is             :1/test/114b8d92dfe9d1c38719135bc885a2220636eca3.jpg
# Image feature vector saved to   :1/test/114b8d92dfe9d1c38719135bc885a2220636eca3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :43
# Image in process is             :1/test/9b79dd411d42124016196b989bdf314838f48de2.jpg
# Image feature vector saved to   :1/test/9b79dd411d42124016196b989bdf314838f48de2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :44
# Image in process is             :1/test/2ed31f58c2be08027b4d060dca7b80d905e9213b.jpg
# Image feature vector saved to   :1/test/2ed31f58c2be08027b4d060dca7b80d905e9213b.npz
# -----------------------------------------------------------------------------------------
# Image count                     :45
# Image in process is             :1/test/b2215523a1384c5583588a831b1a008e94ab2236.jpg
# Image feature vector saved to   :1/test/b2215523a1384c5583588a831b1a008e94ab2236.npz
# -----------------------------------------------------------------------------------------
# Image count                     :46
# Image in process is             :1/test/2e7d3fa1d6bb03ec34328e705c23808f4bf11f76.jpg
# Image feature vector saved to   :1/test/2e7d3fa1d6bb03ec34328e705c23808f4bf11f76.npz
# -----------------------------------------------------------------------------------------
# Image count                     :47
# Image in process is             :1/test/6e98e17cfef862fa83abdf351a23310d608b2b20.jpg
# Image feature vector saved to   :1/test/6e98e17cfef862fa83abdf351a23310d608b2b20.npz
# -----------------------------------------------------------------------------------------
# Image count                     :48
# Image in process is             :1/test/aeb31fa7538c4c38743afe3b5d181ffc2c504427.jpg
# Image feature vector saved to   :1/test/aeb31fa7538c4c38743afe3b5d181ffc2c504427.npz
# -----------------------------------------------------------------------------------------
# Image count                     :49
# Image in process is             :1/test/a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7.jpg
# Image feature vector saved to   :1/test/a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7.npz
# -----------------------------------------------------------------------------------------
# Image count                     :50
# Image in process is             :1/test/bfa750035da255ec6d0f71df34ac3a759e801bbf.jpg
# Image feature vector saved to   :1/test/bfa750035da255ec6d0f71df34ac3a759e801bbf.npz
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors - Completed at Sun Apr  3 10:52:17 2022
# --- 0.16 minutes passed ---------
# --- 50 images processed ---------
# ---------------------------------
# Step.1 - ANNOY index generation - Started at Sun Apr  3 10:52:17 2022
# ---------------------------------
# {'imageName': '6e98e17cfef862fa83abdf351a23310d608b2b20', 'productId': 'YAR45028'}
# ---------------------------------
# Annoy index     : 0
# Image file name : 6e98e17cfef862fa83abdf351a23310d608b2b20
# Product id      : YAR45028
# --- 0.00 minutes passed ---------
# {'imageName': '9b79dd411d42124016196b989bdf314838f48de2', 'productId': 'YAR45067'}
# ---------------------------------
# Annoy index     : 1
# Image file name : 9b79dd411d42124016196b989bdf314838f48de2
# Product id      : YAR45067
# --- 0.01 minutes passed ---------
# {'imageName': '77e23064334f0ab47f9bd17e232bdd941b2e6c1d', 'productId': 'YAR44999'}
# ---------------------------------
# Annoy index     : 2
# Image file name : 77e23064334f0ab47f9bd17e232bdd941b2e6c1d
# Product id      : YAR44999
# --- 0.01 minutes passed ---------
# {'imageName': '158c42c84260dafc49793ce3a2e7fac1b73fba5e', 'productId': 'YAR45013'}
# ---------------------------------
# Annoy index     : 3
# Image file name : 158c42c84260dafc49793ce3a2e7fac1b73fba5e
# Product id      : YAR45013
# --- 0.01 minutes passed ---------
# {'imageName': 'b2215523a1384c5583588a831b1a008e94ab2236', 'productId': 'YAR45794'}
# ---------------------------------
# Annoy index     : 4
# Image file name : b2215523a1384c5583588a831b1a008e94ab2236
# Product id      : YAR45794
# --- 0.01 minutes passed ---------
# {'imageName': 'a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7', 'productId': 'YAR45091'}
# ---------------------------------
# Annoy index     : 5
# Image file name : a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7
# Product id      : YAR45091
# --- 0.02 minutes passed ---------
# {'imageName': 'd8b30ba9b6f342c670ca0086857926cbbad4508d', 'productId': 'YAR44997'}
# ---------------------------------
# Annoy index     : 6
# Image file name : d8b30ba9b6f342c670ca0086857926cbbad4508d
# Product id      : YAR44997
# --- 0.02 minutes passed ---------
# {'imageName': 'b585040bac837350fe18272763a73b9ac069aa09', 'productId': 'YAR45046'}
# ---------------------------------
# Annoy index     : 7
# Image file name : b585040bac837350fe18272763a73b9ac069aa09
# Product id      : YAR45046
# --- 0.02 minutes passed ---------
# {'imageName': 'f4748df6bae208df39ac33e4d2e88ef51673666a', 'productId': 'YAR45036'}
# ---------------------------------
# Annoy index     : 8
# Image file name : f4748df6bae208df39ac33e4d2e88ef51673666a
# Product id      : YAR45036
# --- 0.02 minutes passed ---------
# {'imageName': 'bfa750035da255ec6d0f71df34ac3a759e801bbf', 'productId': 'YAR31406'}
# ---------------------------------
# Annoy index     : 9
# Image file name : bfa750035da255ec6d0f71df34ac3a759e801bbf
# Product id      : YAR31406
# --- 0.03 minutes passed ---------
# {'imageName': '8893ea64a332765217b26680f925342a1bb4d301', 'productId': 'YAR45084'}
# ---------------------------------
# Annoy index     : 10
# Image file name : 8893ea64a332765217b26680f925342a1bb4d301
# Product id      : YAR45084
# --- 0.03 minutes passed ---------
# {'imageName': '22abf56814e371a73528d22848889f84168dc29a', 'productId': 'YAR45010'}
# ---------------------------------
# Annoy index     : 11
# Image file name : 22abf56814e371a73528d22848889f84168dc29a
# Product id      : YAR45010
# --- 0.03 minutes passed ---------
# {'imageName': 'f7aaabd886d4f7b8736dcb4055abd94301dc846d', 'productId': 'YAR45022'}
# ---------------------------------
# Annoy index     : 12
# Image file name : f7aaabd886d4f7b8736dcb4055abd94301dc846d
# Product id      : YAR45022
# --- 0.03 minutes passed ---------
# {'imageName': 'dc09ad64aa6f60ae863d2547652d89d2a1e4f508', 'productId': 'YAR44995'}
# ---------------------------------
# Annoy index     : 13
# Image file name : dc09ad64aa6f60ae863d2547652d89d2a1e4f508
# Product id      : YAR44995
# --- 0.04 minutes passed ---------
# {'imageName': 'e5dddf21df0ffefc2b3b6848c701b28d42477dec', 'productId': 'YAR31435'}
# ---------------------------------
# Annoy index     : 14
# Image file name : e5dddf21df0ffefc2b3b6848c701b28d42477dec
# Product id      : YAR31435
# --- 0.04 minutes passed ---------
# {'imageName': '535d914ddb7bedac122a9c158012a52defbdb28e', 'productId': 'YAR31481'}
# ---------------------------------
# Annoy index     : 15
# Image file name : 535d914ddb7bedac122a9c158012a52defbdb28e
# Product id      : YAR31481
# --- 0.04 minutes passed ---------
# {'imageName': '9769d5e06b3981d39dc1891d6da2ce8462c1c0a3', 'productId': 'YAR45041'}
# ---------------------------------
# Annoy index     : 16
# Image file name : 9769d5e06b3981d39dc1891d6da2ce8462c1c0a3
# Product id      : YAR45041
# --- 0.05 minutes passed ---------
# {'imageName': '114b8d92dfe9d1c38719135bc885a2220636eca3', 'productId': 'YAR45086'}
# ---------------------------------
# Annoy index     : 17
# Image file name : 114b8d92dfe9d1c38719135bc885a2220636eca3
# Product id      : YAR45086
# --- 0.05 minutes passed ---------
# {'imageName': '4dad9e43db72c2609856b02abced3755ef566383', 'productId': 'YAR44988'}
# ---------------------------------
# Annoy index     : 18
# Image file name : 4dad9e43db72c2609856b02abced3755ef566383
# Product id      : YAR44988
# --- 0.05 minutes passed ---------
# {'imageName': '8e021fac89810edd9a8529814ecab1573d68b084', 'productId': 'YAR45009'}
# ---------------------------------
# Annoy index     : 19
# Image file name : 8e021fac89810edd9a8529814ecab1573d68b084
# Product id      : YAR45009
# --- 0.05 minutes passed ---------
# {'imageName': 'a18b4d927b103b36451835047f7a1c223908f228', 'productId': 'YAR45016'}
# ---------------------------------
# Annoy index     : 20
# Image file name : a18b4d927b103b36451835047f7a1c223908f228
# Product id      : YAR45016
# --- 0.06 minutes passed ---------
# {'imageName': '0b96264a36e951c2cb4fba7c3cd913fc0274cba4', 'productId': 'YAR45062'}
# ---------------------------------
# Annoy index     : 21
# Image file name : 0b96264a36e951c2cb4fba7c3cd913fc0274cba4
# Product id      : YAR45062
# --- 0.06 minutes passed ---------
# {'imageName': 'a9e393eb434fe21bd20f718c4c752f819d3acba3', 'productId': 'YAR45012'}
# ---------------------------------
# Annoy index     : 22
# Image file name : a9e393eb434fe21bd20f718c4c752f819d3acba3
# Product id      : YAR45012
# --- 0.06 minutes passed ---------
# {'imageName': '0536ef5660e47128e9fde8a25f547db0785b2851', 'productId': 'YAR45026'}
# ---------------------------------
# Annoy index     : 23
# Image file name : 0536ef5660e47128e9fde8a25f547db0785b2851
# Product id      : YAR45026
# --- 0.06 minutes passed ---------
# {'imageName': 'f170378bdd1be7568992468443d7454e1f3d24f9', 'productId': 'YAR45035'}
# ---------------------------------
# Annoy index     : 24
# Image file name : f170378bdd1be7568992468443d7454e1f3d24f9
# Product id      : YAR45035
# --- 0.07 minutes passed ---------
# {'imageName': 'bb41ffeba7262ad30e7e76d7ba6cce2904c90782', 'productId': 'YAR45923'}
# ---------------------------------
# Annoy index     : 25
# Image file name : bb41ffeba7262ad30e7e76d7ba6cce2904c90782
# Product id      : YAR45923
# --- 0.07 minutes passed ---------
# {'imageName': '46921cd403370e7ab8a098843adaf29cb230537d', 'productId': 'YAR44990'}
# ---------------------------------
# Annoy index     : 26
# Image file name : 46921cd403370e7ab8a098843adaf29cb230537d
# Product id      : YAR44990
# --- 0.07 minutes passed ---------
# {'imageName': 'aeb31fa7538c4c38743afe3b5d181ffc2c504427', 'productId': 'YAR45005'}
# ---------------------------------
# Annoy index     : 27
# Image file name : aeb31fa7538c4c38743afe3b5d181ffc2c504427
# Product id      : YAR45005
# --- 0.07 minutes passed ---------
# {'imageName': '2ed31f58c2be08027b4d060dca7b80d905e9213b', 'productId': 'YAR45004'}
# ---------------------------------
# Annoy index     : 28
# Image file name : 2ed31f58c2be08027b4d060dca7b80d905e9213b
# Product id      : YAR45004
# --- 0.08 minutes passed ---------
# {'imageName': '14f54167bfbf4393f0990334efb292242576bb51', 'productId': 'YAR45025'}
# ---------------------------------
# Annoy index     : 29
# Image file name : 14f54167bfbf4393f0990334efb292242576bb51
# Product id      : YAR45025
# --- 0.08 minutes passed ---------
# {'imageName': '76e7932694833640c2af61030e40fd72997e7e24', 'productId': 'YAR45068'}
# ---------------------------------
# Annoy index     : 30
# Image file name : 76e7932694833640c2af61030e40fd72997e7e24
# Product id      : YAR45068
# --- 0.08 minutes passed ---------
# {'imageName': '3093418aba5897313303ae15e43275671fabe473', 'productId': 'YAR44992'}
# ---------------------------------
# Annoy index     : 31
# Image file name : 3093418aba5897313303ae15e43275671fabe473
# Product id      : YAR44992
# --- 0.08 minutes passed ---------
# {'imageName': '9e34b9687d45408f7c739e020bb38ae7e562e23f', 'productId': 'YAR45027'}
# ---------------------------------
# Annoy index     : 32
# Image file name : 9e34b9687d45408f7c739e020bb38ae7e562e23f
# Product id      : YAR45027
# --- 0.09 minutes passed ---------
# {'imageName': '4a2f509d8e9def9dd5681d36c3045f648dc6e1bf', 'productId': 'YAR44996'}
# ---------------------------------
# Annoy index     : 33
# Image file name : 4a2f509d8e9def9dd5681d36c3045f648dc6e1bf
# Product id      : YAR44996
# --- 0.09 minutes passed ---------
# {'imageName': '0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46', 'productId': 'YAR45081'}
# ---------------------------------
# Annoy index     : 34
# Image file name : 0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46
# Product id      : YAR45081
# --- 0.09 minutes passed ---------
# {'imageName': 'cd8320501898da6979a844f621b3a97f9f76ba0c', 'productId': 'YAR31474'}
# ---------------------------------
# Annoy index     : 35
# Image file name : cd8320501898da6979a844f621b3a97f9f76ba0c
# Product id      : YAR31474
# --- 0.09 minutes passed ---------
# {'imageName': 'c2535cf647be0949529ddb8e78beaaf79ac0bd53', 'productId': 'YAR45970'}
# ---------------------------------
# Annoy index     : 36
# Image file name : c2535cf647be0949529ddb8e78beaaf79ac0bd53
# Product id      : YAR45970
# --- 0.10 minutes passed ---------
# {'imageName': 'e95a8e4c52075aaa389d3d2b031c39c5570a1d99', 'productId': 'YAR45034'}
# ---------------------------------
# Annoy index     : 37
# Image file name : e95a8e4c52075aaa389d3d2b031c39c5570a1d99
# Product id      : YAR45034
# --- 0.10 minutes passed ---------
# {'imageName': 'fd27283a5a01a7a4d4b153d4de4b38117a94f4b8', 'productId': 'YAR45065'}
# ---------------------------------
# Annoy index     : 38
# Image file name : fd27283a5a01a7a4d4b153d4de4b38117a94f4b8
# Product id      : YAR45065
# --- 0.10 minutes passed ---------
# {'imageName': 'b3179a1855d492eb3313b59b82a1e29e8850eb92', 'productId': 'YAR45014'}
# ---------------------------------
# Annoy index     : 39
# Image file name : b3179a1855d492eb3313b59b82a1e29e8850eb92
# Product id      : YAR45014
# --- 0.11 minutes passed ---------
# {'imageName': '5b7ea4ab23dfd89d1a66ae2f256826e5c8783140', 'productId': 'YAR45066'}
# ---------------------------------
# Annoy index     : 40
# Image file name : 5b7ea4ab23dfd89d1a66ae2f256826e5c8783140
# Product id      : YAR45066
# --- 0.11 minutes passed ---------
# {'imageName': '2e7d3fa1d6bb03ec34328e705c23808f4bf11f76', 'productId': 'YAR44994'}
# ---------------------------------
# Annoy index     : 41
# Image file name : 2e7d3fa1d6bb03ec34328e705c23808f4bf11f76
# Product id      : YAR44994
# --- 0.11 minutes passed ---------
# {'imageName': '623b50a4f2965c9fe8c453487dd288f998b51297', 'productId': 'YAR45896'}
# ---------------------------------
# Annoy index     : 42
# Image file name : 623b50a4f2965c9fe8c453487dd288f998b51297
# Product id      : YAR45896
# --- 0.12 minutes passed ---------
# {'imageName': '73359c7cf3b04499250039ccb456eb168afa8704', 'productId': 'YAR45047'}
# ---------------------------------
# Annoy index     : 43
# Image file name : 73359c7cf3b04499250039ccb456eb168afa8704
# Product id      : YAR45047
# --- 0.12 minutes passed ---------
# {'imageName': 'a940aa2eb44907bb22ad16182df5dd093b97e38c', 'productId': 'YAR45151'}
# ---------------------------------
# Annoy index     : 44
# Image file name : a940aa2eb44907bb22ad16182df5dd093b97e38c
# Product id      : YAR45151
# --- 0.12 minutes passed ---------
# {'imageName': 'f5d05c38a69a94a93fec7e8ee357d701dc2308d9', 'productId': 'YAR45083'}
# ---------------------------------
# Annoy index     : 45
# Image file name : f5d05c38a69a94a93fec7e8ee357d701dc2308d9
# Product id      : YAR45083
# --- 0.13 minutes passed ---------
# {'imageName': 'c715c4465c351f0b06415fb9a1ccbd946327fb23', 'productId': 'YAR45061'}
# ---------------------------------
# Annoy index     : 46
# Image file name : c715c4465c351f0b06415fb9a1ccbd946327fb23
# Product id      : YAR45061
# --- 0.13 minutes passed ---------
# {'imageName': 'bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf', 'productId': 'YAR45795'}
# ---------------------------------
# Annoy index     : 47
# Image file name : bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf
# Product id      : YAR45795
# --- 0.13 minutes passed ---------
# {'imageName': 'c2c0fff79e0b65a818412572e9f9364bc359fb4f', 'productId': 'YAR45003'}
# ---------------------------------
# Annoy index     : 48
# Image file name : c2c0fff79e0b65a818412572e9f9364bc359fb4f
# Product id      : YAR45003
# --- 0.13 minutes passed ---------
# {'imageName': 'cba20840f15f48fae6ddaacac0721df80ae63ad8', 'productId': 'YAR45033'}
# ---------------------------------
# Annoy index     : 49
# Image file name : cba20840f15f48fae6ddaacac0721df80ae63ad8
# Product id      : YAR45033
# --- 0.14 minutes passed ---------
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started
# 0
# 9
# 34
# 17
# 45
# 31
# 29
# 6
# 28
# 49
# 12
# 37
# 19
# 35
# 3
# 43
# 1
# 44
# 24
# 10
# ---------------------------------
# Similarity index       : 0
# Master Image file name : 6e98e17cfef862fa83abdf351a23310d608b2b20
# Nearest Neighbors.     : [0, 9, 34, 17, 45, 31, 29, 6, 28, 49, 12, 37, 19, 35, 3, 43, 1, 44, 24, 10]
# --- 0.14 minutes passed ---------
# 1
# 49
# 37
# 33
# 40
# 46
# 38
# 28
# 22
# 5
# 8
# 12
# 19
# 16
# 7
# 36
# 11
# 17
# 48
# 23
# ---------------------------------
# Similarity index       : 1
# Master Image file name : 9b79dd411d42124016196b989bdf314838f48de2
# Nearest Neighbors.     : [1, 49, 37, 33, 40, 46, 38, 28, 22, 5, 8, 12, 19, 16, 7, 36, 11, 17, 48, 23]
# --- 0.14 minutes passed ---------
# 2
# 25
# 14
# 44
# 29
# 24
# 30
# 21
# 35
# 45
# 46
# 20
# 43
# 16
# 6
# 28
# 36
# 47
# 40
# 8
# ---------------------------------
# Similarity index       : 2
# Master Image file name : 77e23064334f0ab47f9bd17e232bdd941b2e6c1d
# Nearest Neighbors.     : [2, 25, 14, 44, 29, 24, 30, 21, 35, 45, 46, 20, 43, 16, 6, 28, 36, 47, 40, 8]
# --- 0.14 minutes passed ---------
# 3
# 26
# 12
# 27
# 41
# 48
# 37
# 49
# 33
# 23
# 11
# 1
# 13
# 16
# 29
# 8
# 15
# 38
# 40
# 46
# ---------------------------------
# Similarity index       : 3
# Master Image file name : 158c42c84260dafc49793ce3a2e7fac1b73fba5e
# Nearest Neighbors.     : [3, 26, 12, 27, 41, 48, 37, 49, 33, 23, 11, 1, 13, 16, 29, 8, 15, 38, 40, 46]
# --- 0.14 minutes passed ---------
# 4
# 34
# 6
# 45
# 24
# 47
# 32
# 14
# 30
# 43
# 17
# 31
# 35
# 19
# 8
# 20
# 22
# 49
# 23
# 2
# ---------------------------------
# Similarity index       : 4
# Master Image file name : b2215523a1384c5583588a831b1a008e94ab2236
# Nearest Neighbors.     : [4, 34, 6, 45, 24, 47, 32, 14, 30, 43, 17, 31, 35, 19, 8, 20, 22, 49, 23, 2]
# --- 0.14 minutes passed ---------
# 5
# 36
# 22
# 16
# 37
# 19
# 28
# 17
# 40
# 8
# 46
# 1
# 34
# 38
# 49
# 7
# 10
# 45
# 32
# 14
# ---------------------------------
# Similarity index       : 5
# Master Image file name : a14ac90619fa5b7feb187ead4d4d42ae9c59d7a7
# Nearest Neighbors.     : [5, 36, 22, 16, 37, 19, 28, 17, 40, 8, 46, 1, 34, 38, 49, 7, 10, 45, 32, 14]
# --- 0.14 minutes passed ---------
# 6
# 45
# 4
# 47
# 34
# 24
# 32
# 14
# 35
# 49
# 8
# 29
# 2
# 28
# 10
# 19
# 43
# 17
# 31
# 16
# ---------------------------------
# Similarity index       : 6
# Master Image file name : d8b30ba9b6f342c670ca0086857926cbbad4508d
# Nearest Neighbors.     : [6, 45, 4, 47, 34, 24, 32, 14, 35, 49, 8, 29, 2, 28, 10, 19, 43, 17, 31, 16]
# --- 0.15 minutes passed ---------
# 7
# 37
# 46
# 22
# 49
# 8
# 38
# 40
# 16
# 36
# 1
# 19
# 28
# 5
# 24
# 47
# 48
# 29
# 6
# 33
# ---------------------------------
# Similarity index       : 7
# Master Image file name : b585040bac837350fe18272763a73b9ac069aa09
# Nearest Neighbors.     : [7, 37, 46, 22, 49, 8, 38, 40, 16, 36, 1, 19, 28, 5, 24, 47, 48, 29, 6, 33]
# --- 0.15 minutes passed ---------
# 8
# 49
# 16
# 22
# 38
# 36
# 28
# 7
# 5
# 37
# 42
# 23
# 1
# 40
# 46
# 19
# 35
# 32
# 17
# 14
# ---------------------------------
# Similarity index       : 8
# Master Image file name : f4748df6bae208df39ac33e4d2e88ef51673666a
# Nearest Neighbors.     : [8, 49, 16, 22, 38, 36, 28, 7, 5, 37, 42, 23, 1, 40, 46, 19, 35, 32, 17, 14]
# --- 0.15 minutes passed ---------
# 9
# 39
# 31
# 17
# 35
# 28
# 0
# 18
# 49
# 10
# 45
# 34
# 32
# 12
# 8
# 16
# 1
# 5
# 42
# 37
# ---------------------------------
# Similarity index       : 9
# Master Image file name : bfa750035da255ec6d0f71df34ac3a759e801bbf
# Nearest Neighbors.     : [9, 39, 31, 17, 35, 28, 0, 18, 49, 10, 45, 34, 32, 12, 8, 16, 1, 5, 42, 37]
# --- 0.15 minutes passed ---------
# 10
# 17
# 45
# 16
# 32
# 47
# 28
# 5
# 43
# 40
# 8
# 22
# 19
# 39
# 36
# 6
# 38
# 46
# 37
# 35
# ---------------------------------
# Similarity index       : 10
# Master Image file name : 8893ea64a332765217b26680f925342a1bb4d301
# Nearest Neighbors.     : [10, 17, 45, 16, 32, 47, 28, 5, 43, 40, 8, 22, 19, 39, 36, 6, 38, 46, 37, 35]
# --- 0.15 minutes passed ---------
# 11
# 33
# 37
# 1
# 12
# 40
# 48
# 3
# 27
# 26
# 7
# 49
# 46
# 41
# 36
# 38
# 16
# 19
# 23
# 22
# ---------------------------------
# Similarity index       : 11
# Master Image file name : 22abf56814e371a73528d22848889f84168dc29a
# Nearest Neighbors.     : [11, 33, 37, 1, 12, 40, 48, 3, 27, 26, 7, 49, 46, 41, 36, 38, 16, 19, 23, 22]
# --- 0.15 minutes passed ---------
# 12
# 26
# 3
# 37
# 1
# 33
# 48
# 27
# 49
# 41
# 11
# 9
# 28
# 46
# 39
# 40
# 16
# 5
# 23
# 38
# ---------------------------------
# Similarity index       : 12
# Master Image file name : f7aaabd886d4f7b8736dcb4055abd94301dc846d
# Nearest Neighbors.     : [12, 26, 3, 37, 1, 33, 48, 27, 49, 41, 11, 9, 28, 46, 39, 40, 16, 5, 23, 38]
# --- 0.15 minutes passed ---------
# 13
# 38
# 48
# 41
# 46
# 15
# 40
# 16
# 37
# 36
# 8
# 32
# 23
# 3
# 35
# 1
# 28
# 18
# 12
# 49
# ---------------------------------
# Similarity index       : 13
# Master Image file name : dc09ad64aa6f60ae863d2547652d89d2a1e4f508
# Nearest Neighbors.     : [13, 38, 48, 41, 46, 15, 40, 16, 37, 36, 8, 32, 23, 3, 35, 1, 28, 18, 12, 49]
# --- 0.15 minutes passed ---------
# 14
# 2
# 24
# 45
# 46
# 35
# 16
# 21
# 47
# 29
# 40
# 30
# 6
# 34
# 36
# 25
# 44
# 38
# 8
# 43
# ---------------------------------
# Similarity index       : 14
# Master Image file name : e5dddf21df0ffefc2b3b6848c701b28d42477dec
# Nearest Neighbors.     : [14, 2, 24, 45, 46, 35, 16, 21, 47, 29, 40, 30, 6, 34, 36, 25, 44, 38, 8, 43]
# --- 0.15 minutes passed ---------
# 15
# 18
# 38
# 35
# 13
# 39
# 43
# 46
# 40
# 16
# 30
# 14
# 8
# 24
# 2
# 20
# 37
# 29
# 36
# 21
# ---------------------------------
# Similarity index       : 15
# Master Image file name : 535d914ddb7bedac122a9c158012a52defbdb28e
# Nearest Neighbors.     : [15, 18, 38, 35, 13, 39, 43, 46, 40, 16, 30, 14, 8, 24, 2, 20, 37, 29, 36, 21]
# --- 0.15 minutes passed ---------
# 16
# 36
# 38
# 40
# 8
# 28
# 46
# 5
# 22
# 37
# 49
# 7
# 42
# 17
# 1
# 32
# 14
# 10
# 23
# 43
# ---------------------------------
# Similarity index       : 16
# Master Image file name : 9769d5e06b3981d39dc1891d6da2ce8462c1c0a3
# Nearest Neighbors.     : [16, 36, 38, 40, 8, 28, 46, 5, 22, 37, 49, 7, 42, 17, 1, 32, 14, 10, 23, 43]
# --- 0.15 minutes passed ---------
# 17
# 34
# 5
# 16
# 22
# 28
# 10
# 32
# 49
# 42
# 37
# 9
# 8
# 45
# 23
# 19
# 36
# 1
# 4
# 31
# ---------------------------------
# Similarity index       : 17
# Master Image file name : 114b8d92dfe9d1c38719135bc885a2220636eca3
# Nearest Neighbors.     : [17, 34, 5, 16, 22, 28, 10, 32, 49, 42, 37, 9, 8, 45, 23, 19, 36, 1, 4, 31]
# --- 0.15 minutes passed ---------
# 18
# 15
# 39
# 31
# 43
# 35
# 47
# 9
# 10
# 38
# 32
# 30
# 28
# 40
# 45
# 13
# 37
# 24
# 8
# 42
# ---------------------------------
# Similarity index       : 18
# Master Image file name : 4dad9e43db72c2609856b02abced3755ef566383
# Nearest Neighbors.     : [18, 15, 39, 31, 43, 35, 47, 9, 10, 38, 32, 30, 28, 40, 45, 13, 37, 24, 8, 42]
# --- 0.15 minutes passed ---------
# 19
# 22
# 5
# 28
# 49
# 1
# 7
# 8
# 37
# 36
# 34
# 33
# 17
# 10
# 16
# 32
# 24
# 6
# 45
# 47
# ---------------------------------
# Similarity index       : 19
# Master Image file name : 8e021fac89810edd9a8529814ecab1573d68b084
# Nearest Neighbors.     : [19, 22, 5, 28, 49, 1, 7, 8, 37, 36, 34, 33, 17, 10, 16, 32, 24, 6, 45, 47]
# --- 0.15 minutes passed ---------
# 20
# 42
# 23
# 35
# 41
# 2
# 43
# 8
# 16
# 32
# 45
# 14
# 34
# 6
# 4
# 30
# 24
# 15
# 36
# 47
# ---------------------------------
# Similarity index       : 20
# Master Image file name : a18b4d927b103b36451835047f7a1c223908f228
# Nearest Neighbors.     : [20, 42, 23, 35, 41, 2, 43, 8, 16, 32, 45, 14, 34, 6, 4, 30, 24, 15, 36, 47]
# --- 0.15 minutes passed ---------
# 21
# 30
# 24
# 25
# 14
# 44
# 47
# 2
# 43
# 46
# 29
# 40
# 38
# 45
# 15
# 28
# 4
# 16
# 8
# 32
# ---------------------------------
# Similarity index       : 21
# Master Image file name : 0b96264a36e951c2cb4fba7c3cd913fc0274cba4
# Nearest Neighbors.     : [21, 30, 24, 25, 14, 44, 47, 2, 43, 46, 29, 40, 38, 45, 15, 28, 4, 16, 8, 32]
# --- 0.15 minutes passed ---------
# 22
# 5
# 36
# 8
# 19
# 16
# 49
# 28
# 7
# 40
# 37
# 1
# 17
# 38
# 46
# 34
# 42
# 32
# 10
# 23
# ---------------------------------
# Similarity index       : 22
# Master Image file name : a9e393eb434fe21bd20f718c4c752f819d3acba3
# Nearest Neighbors.     : [22, 5, 36, 8, 19, 16, 49, 28, 7, 40, 37, 1, 17, 38, 46, 34, 42, 32, 10, 23]
# --- 0.15 minutes passed ---------
# 23
# 42
# 41
# 8
# 48
# 20
# 49
# 16
# 32
# 35
# 34
# 17
# 36
# 22
# 37
# 1
# 40
# 38
# 3
# 5
# ---------------------------------
# Similarity index       : 23
# Master Image file name : 0536ef5660e47128e9fde8a25f547db0785b2851
# Nearest Neighbors.     : [23, 42, 41, 8, 48, 20, 49, 16, 32, 35, 34, 17, 36, 22, 37, 1, 40, 38, 3, 5]
# --- 0.15 minutes passed ---------
# 24
# 47
# 30
# 14
# 21
# 45
# 2
# 4
# 6
# 46
# 44
# 29
# 25
# 35
# 43
# 28
# 7
# 31
# 8
# 34
# ---------------------------------
# Similarity index       : 24
# Master Image file name : f170378bdd1be7568992468443d7454e1f3d24f9
# Nearest Neighbors.     : [24, 47, 30, 14, 21, 45, 2, 4, 6, 46, 44, 29, 25, 35, 43, 28, 7, 31, 8, 34]
# --- 0.15 minutes passed ---------
# 25
# 44
# 2
# 30
# 29
# 21
# 24
# 14
# 28
# 43
# 46
# 45
# 47
# 16
# 20
# 34
# 15
# 49
# 8
# 7
# ---------------------------------
# Similarity index       : 25
# Master Image file name : bb41ffeba7262ad30e7e76d7ba6cce2904c90782
# Nearest Neighbors.     : [25, 44, 2, 30, 29, 21, 24, 14, 28, 43, 46, 45, 47, 16, 20, 34, 15, 49, 8, 7]
# --- 0.16 minutes passed ---------
# 26
# 12
# 3
# 27
# 48
# 37
# 33
# 49
# 1
# 41
# 11
# 23
# 39
# 35
# 40
# 38
# 13
# 46
# 8
# 15
# ---------------------------------
# Similarity index       : 26
# Master Image file name : 46921cd403370e7ab8a098843adaf29cb230537d
# Nearest Neighbors.     : [26, 12, 3, 27, 48, 37, 33, 49, 1, 41, 11, 23, 39, 35, 40, 38, 13, 46, 8, 15]
# --- 0.16 minutes passed ---------
# 27
# 26
# 3
# 48
# 12
# 37
# 41
# 11
# 1
# 33
# 13
# 46
# 49
# 40
# 38
# 15
# 23
# 7
# 29
# 35
# ---------------------------------
# Similarity index       : 27
# Master Image file name : aeb31fa7538c4c38743afe3b5d181ffc2c504427
# Nearest Neighbors.     : [27, 26, 3, 48, 12, 37, 41, 11, 1, 33, 13, 46, 49, 40, 38, 15, 23, 7, 29, 35]
# --- 0.16 minutes passed ---------
# 28
# 16
# 5
# 46
# 37
# 22
# 8
# 1
# 38
# 49
# 19
# 36
# 40
# 17
# 29
# 7
# 10
# 47
# 32
# 24
# ---------------------------------
# Similarity index       : 28
# Master Image file name : 2ed31f58c2be08027b4d060dca7b80d905e9213b
# Nearest Neighbors.     : [28, 16, 5, 46, 37, 22, 8, 1, 38, 49, 19, 36, 40, 17, 29, 7, 10, 47, 32, 24]
# --- 0.16 minutes passed ---------
# 29
# 44
# 25
# 2
# 28
# 24
# 14
# 30
# 46
# 6
# 47
# 45
# 21
# 37
# 16
# 36
# 7
# 41
# 35
# 15
# ---------------------------------
# Similarity index       : 29
# Master Image file name : 14f54167bfbf4393f0990334efb292242576bb51
# Nearest Neighbors.     : [29, 44, 25, 2, 28, 24, 14, 30, 46, 6, 47, 45, 21, 37, 16, 36, 7, 41, 35, 15]
# --- 0.16 minutes passed ---------
# 30
# 21
# 24
# 25
# 47
# 43
# 44
# 2
# 14
# 29
# 45
# 28
# 32
# 31
# 4
# 46
# 15
# 35
# 18
# 34
# ---------------------------------
# Similarity index       : 30
# Master Image file name : 76e7932694833640c2af61030e40fd72997e7e24
# Nearest Neighbors.     : [30, 21, 24, 25, 47, 43, 44, 2, 14, 29, 45, 28, 32, 31, 4, 46, 15, 35, 18, 34]
# --- 0.16 minutes passed ---------
# 31
# 45
# 35
# 43
# 9
# 34
# 18
# 39
# 24
# 47
# 30
# 32
# 4
# 17
# 6
# 49
# 28
# 10
# 14
# 42
# ---------------------------------
# Similarity index       : 31
# Master Image file name : 3093418aba5897313303ae15e43275671fabe473
# Nearest Neighbors.     : [31, 45, 35, 43, 9, 34, 18, 39, 24, 47, 30, 32, 4, 17, 6, 49, 28, 10, 14, 42]
# --- 0.16 minutes passed ---------
# 32
# 34
# 45
# 42
# 16
# 6
# 43
# 17
# 4
# 35
# 36
# 10
# 23
# 47
# 28
# 8
# 22
# 30
# 5
# 14
# ---------------------------------
# Similarity index       : 32
# Master Image file name : 9e34b9687d45408f7c739e020bb38ae7e562e23f
# Nearest Neighbors.     : [32, 34, 45, 42, 16, 6, 43, 17, 4, 35, 36, 10, 23, 47, 28, 8, 22, 30, 5, 14]
# --- 0.16 minutes passed ---------
# 33
# 1
# 37
# 49
# 12
# 11
# 26
# 19
# 48
# 28
# 40
# 5
# 16
# 3
# 22
# 36
# 17
# 7
# 23
# 38
# ---------------------------------
# Similarity index       : 33
# Master Image file name : 4a2f509d8e9def9dd5681d36c3045f648dc6e1bf
# Nearest Neighbors.     : [33, 1, 37, 49, 12, 11, 26, 19, 48, 28, 40, 5, 16, 3, 22, 36, 17, 7, 23, 38]
# --- 0.16 minutes passed ---------
# 34
# 17
# 45
# 32
# 4
# 6
# 5
# 22
# 14
# 49
# 19
# 31
# 23
# 16
# 36
# 35
# 43
# 8
# 24
# 42
# ---------------------------------
# Similarity index       : 34
# Master Image file name : 0b0aa89982b3d9c468ef534a2f74c3fca0a4ca46
# Nearest Neighbors.     : [34, 17, 45, 32, 4, 6, 5, 22, 14, 49, 19, 31, 23, 16, 36, 35, 43, 8, 24, 42]
# --- 0.16 minutes passed ---------
# 35
# 45
# 14
# 31
# 20
# 42
# 24
# 39
# 43
# 32
# 8
# 6
# 15
# 23
# 2
# 9
# 34
# 16
# 38
# 18
# ---------------------------------
# Similarity index       : 35
# Master Image file name : cd8320501898da6979a844f621b3a97f9f76ba0c
# Nearest Neighbors.     : [35, 45, 14, 31, 20, 42, 24, 39, 43, 32, 8, 6, 15, 23, 2, 9, 34, 16, 38, 18]
# --- 0.16 minutes passed ---------
# 36
# 16
# 5
# 40
# 22
# 38
# 46
# 37
# 8
# 28
# 7
# 49
# 1
# 32
# 14
# 19
# 23
# 34
# 17
# 47
# ---------------------------------
# Similarity index       : 36
# Master Image file name : c2535cf647be0949529ddb8e78beaaf79ac0bd53
# Nearest Neighbors.     : [36, 16, 5, 40, 22, 38, 46, 37, 8, 28, 7, 49, 1, 32, 14, 19, 23, 34, 17, 47]
# --- 0.16 minutes passed ---------
# 37
# 1
# 46
# 40
# 49
# 38
# 5
# 16
# 7
# 28
# 36
# 33
# 22
# 12
# 8
# 48
# 19
# 11
# 17
# 26
# ---------------------------------
# Similarity index       : 37
# Master Image file name : e95a8e4c52075aaa389d3d2b031c39c5570a1d99
# Nearest Neighbors.     : [37, 1, 46, 40, 49, 38, 5, 16, 7, 28, 36, 33, 22, 12, 8, 48, 19, 11, 17, 26]
# --- 0.17 minutes passed ---------
# 38
# 40
# 46
# 16
# 37
# 36
# 8
# 49
# 1
# 7
# 28
# 13
# 22
# 5
# 15
# 48
# 14
# 39
# 35
# 24
# ---------------------------------
# Similarity index       : 38
# Master Image file name : fd27283a5a01a7a4d4b153d4de4b38117a94f4b8
# Nearest Neighbors.     : [38, 40, 46, 16, 37, 36, 8, 49, 1, 7, 28, 13, 22, 5, 15, 48, 14, 39, 35, 24]
# --- 0.17 minutes passed ---------
# 39
# 9
# 35
# 18
# 15
# 38
# 31
# 8
# 49
# 10
# 16
# 32
# 37
# 28
# 40
# 42
# 12
# 1
# 17
# 43
# ---------------------------------
# Similarity index       : 39
# Master Image file name : b3179a1855d492eb3313b59b82a1e29e8850eb92
# Nearest Neighbors.     : [39, 9, 35, 18, 15, 38, 31, 8, 49, 10, 16, 32, 37, 28, 40, 42, 12, 1, 17, 43]
# --- 0.17 minutes passed ---------
# 40
# 38
# 46
# 37
# 16
# 36
# 1
# 49
# 22
# 5
# 7
# 28
# 8
# 14
# 48
# 13
# 10
# 47
# 15
# 24
# ---------------------------------
# Similarity index       : 40
# Master Image file name : 5b7ea4ab23dfd89d1a66ae2f256826e5c8783140
# Nearest Neighbors.     : [40, 38, 46, 37, 16, 36, 1, 49, 22, 5, 7, 28, 8, 14, 48, 13, 10, 47, 15, 24]
# --- 0.17 minutes passed ---------
# 41
# 48
# 23
# 3
# 42
# 13
# 20
# 37
# 12
# 16
# 38
# 35
# 26
# 8
# 49
# 40
# 27
# 36
# 29
# 28
# ---------------------------------
# Similarity index       : 41
# Master Image file name : 2e7d3fa1d6bb03ec34328e705c23808f4bf11f76
# Nearest Neighbors.     : [41, 48, 23, 3, 42, 13, 20, 37, 12, 16, 38, 35, 26, 8, 49, 40, 27, 36, 29, 28]
# --- 0.17 minutes passed ---------
# 42
# 23
# 20
# 8
# 32
# 16
# 35
# 41
# 17
# 22
# 28
# 49
# 34
# 36
# 45
# 5
# 10
# 39
# 43
# 48
# ---------------------------------
# Similarity index       : 42
# Master Image file name : 623b50a4f2965c9fe8c453487dd288f998b51297
# Nearest Neighbors.     : [42, 23, 20, 8, 32, 16, 35, 41, 17, 22, 28, 49, 34, 36, 45, 5, 10, 39, 43, 48]
# --- 0.17 minutes passed ---------
# 43
# 47
# 30
# 45
# 32
# 35
# 24
# 31
# 21
# 16
# 10
# 14
# 2
# 34
# 18
# 15
# 20
# 4
# 6
# 8
# ---------------------------------
# Similarity index       : 43
# Master Image file name : 73359c7cf3b04499250039ccb456eb168afa8704
# Nearest Neighbors.     : [43, 47, 30, 45, 32, 35, 24, 31, 21, 16, 10, 14, 2, 34, 18, 15, 20, 4, 6, 8]
# --- 0.17 minutes passed ---------
# 44
# 25
# 29
# 2
# 30
# 24
# 21
# 14
# 28
# 45
# 46
# 43
# 47
# 5
# 34
# 36
# 19
# 6
# 16
# 35
# ---------------------------------
# Similarity index       : 44
# Master Image file name : a940aa2eb44907bb22ad16182df5dd093b97e38c
# Nearest Neighbors.     : [44, 25, 29, 2, 30, 24, 21, 14, 28, 45, 46, 43, 47, 5, 34, 36, 19, 6, 16, 35]
# --- 0.17 minutes passed ---------
# 45
# 47
# 34
# 6
# 14
# 24
# 4
# 35
# 31
# 32
# 43
# 10
# 30
# 17
# 2
# 5
# 16
# 28
# 22
# 36
# ---------------------------------
# Similarity index       : 45
# Master Image file name : f5d05c38a69a94a93fec7e8ee357d701dc2308d9
# Nearest Neighbors.     : [45, 47, 34, 6, 14, 24, 4, 35, 31, 32, 43, 10, 30, 17, 2, 5, 16, 28, 22, 36]
# --- 0.17 minutes passed ---------
# 46
# 40
# 38
# 37
# 16
# 36
# 28
# 1
# 7
# 49
# 14
# 5
# 8
# 24
# 22
# 47
# 13
# 2
# 21
# 29
# ---------------------------------
# Similarity index       : 46
# Master Image file name : c715c4465c351f0b06415fb9a1ccbd946327fb23
# Nearest Neighbors.     : [46, 40, 38, 37, 16, 36, 28, 1, 7, 49, 14, 5, 8, 24, 22, 47, 13, 2, 21, 29]
# --- 0.17 minutes passed ---------
# 47
# 24
# 45
# 30
# 43
# 6
# 4
# 14
# 21
# 10
# 28
# 32
# 46
# 31
# 36
# 49
# 40
# 16
# 22
# 38
# ---------------------------------
# Similarity index       : 47
# Master Image file name : bc5abcac7a0c9ea0e6eb2be8a6b17921fed84bdf
# Nearest Neighbors.     : [47, 24, 45, 30, 43, 6, 4, 14, 21, 10, 28, 32, 46, 31, 36, 49, 40, 16, 22, 38]
# --- 0.17 minutes passed ---------
# 48
# 41
# 23
# 37
# 13
# 3
# 26
# 38
# 27
# 12
# 40
# 33
# 16
# 1
# 49
# 46
# 7
# 11
# 36
# 42
# ---------------------------------
# Similarity index       : 48
# Master Image file name : c2c0fff79e0b65a818412572e9f9364bc359fb4f
# Nearest Neighbors.     : [48, 41, 23, 37, 13, 3, 26, 38, 27, 12, 40, 33, 16, 1, 49, 46, 7, 11, 36, 42]
# --- 0.17 minutes passed ---------
# 49
# 1
# 37
# 8
# 22
# 40
# 33
# 46
# 38
# 16
# 7
# 28
# 19
# 36
# 23
# 5
# 17
# 34
# 12
# 6
# ---------------------------------
# Similarity index       : 49
# Master Image file name : cba20840f15f48fae6ddaacac0721df80ae63ad8
# Nearest Neighbors.     : [49, 1, 37, 8, 22, 40, 33, 46, 38, 16, 7, 28, 19, 36, 23, 5, 17, 34, 12, 6]
# --- 0.17 minutes passed ---------
# Step.2 - Similarity score calculation - Finished
# Step.3 - Data stored in 'nearest_neighbors.json' file
# --- Prosess completed in 0.17 minutes ---------
